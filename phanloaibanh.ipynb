# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import load_img
from tensorflow.keras.utils import img_to_array
from tensorflow.keras.optimizers import SGD,Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
from keras.models import Sequential 
from keras.utils import np_utils
from keras.layers import Dense,Activation,Dropout,LSTM,BatchNormalization
from keras.layers import Flatten
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.utils import to_categorical
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
trainset='/content/drive/MyDrive/banh'

# %%
data_generator = ImageDataGenerator(rescale=1./255,validation_split=0.1,width_shift_range=0.2,height_shift_range=0.2,zoom_range=0.2,horizontal_flip=True)

# %%
train_dataset=data_generator.flow_from_directory(trainset,
                                     target_size=(100,100),
                                     batch_size=128,
                                     class_mode='categorical',
                                     subset="training",
                                     shuffle=True,)
validation_set=data_generator.flow_from_directory(trainset,
                                              target_size=(100,100),
                                              batch_size=128,
                                              class_mode='categorical',
                                              subset="validation",
                                              shuffle=True)
# Out:
# Found 72 images belonging to 4 classes.
# Found 8 images belonging to 4 classes.

# %%
validation_set.class_indices
# Out:
# {'banhdalon': 0, 'banhhoi': 1, 'banhuot': 2, 'banhxeo': 3}

# %%
label=['banhdalon','banhhoi','banhuot','banhxeo']

# %%
model = Sequential()
model.add(Conv2D(32,(3,3),activation='relu',kernel_initializer='he_uniform',padding ='same',input_shape=(100,100,3)))
model.add(Conv2D(32,(3,3),activation='relu',kernel_initializer='he_uniform',padding ='same'))
model.add(MaxPooling2D((2,2)))
model.add(Conv2D(64,(3,3),activation='relu',kernel_initializer='he_uniform',padding ='same'))
model.add(Conv2D(64,(3,3),activation='relu',kernel_initializer='he_uniform',padding ='same'))
model.add(MaxPooling2D((2,2)))
model.add(Conv2D(128,(3,3),activation='relu',kernel_initializer='he_uniform',padding ='same'))
model.add(Conv2D(128,(3,3),activation='relu',kernel_initializer='he_uniform',padding ='same'))
model.add(MaxPooling2D((2,2)))
model.add(Flatten())
model.add(Dense(256,activation='relu',kernel_initializer='he_uniform'))
model.add(Dropout(0.2))
model.add(Dense(4,activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.fit(train_dataset,batch_size=128,epochs=100,verbose=1,validation_data=validation_set)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 9s 9s/step - loss: 1.8285 - accuracy: 0.2361 - val_loss: 15.7540 - val_accuracy: 0.2500
# Epoch 2/100
# 1/1 [==============================] - 6s 6s/step - loss: 16.3971 - accuracy: 0.2917 - val_loss: 8.0275 - val_accuracy: 0.2500
# Epoch 3/100
# 1/1 [==============================] - 6s 6s/step - loss: 7.8866 - accuracy: 0.2500 - val_loss: 2.0962 - val_accuracy: 0.2500
# Epoch 4/100
# 1/1 [==============================] - 6s 6s/step - loss: 2.2781 - accuracy: 0.2500 - val_loss: 1.6545 - val_accuracy: 0.3750
# Epoch 5/100
# 1/1 [==============================] - 6s 6s/step - loss: 1.7496 - accuracy: 0.3056 - val_loss: 1.3826 - val_accuracy: 0.2500
# Epoch 6/100
# 1/1 [==============================] - 6s 6s/step - loss: 1.4194 - accuracy: 0.2778 - val_loss: 1.3199 - val_accuracy: 0.2500
# Epoch 7/100
# 1/1 [==============================] - 6s 6s/step - loss: 1.3278 - accuracy: 0.3472 - val_loss: 1.2496 - val_accuracy: 0.5000
# Epoch 8/100
# 1/1 [==============================] - 6s 6s/step - loss: 1.2862 - accuracy: 0.4167 - val_loss: 1.2121 - val_accuracy: 0.5000
# Epoch 9/100
# 1/1 [==============================] - 6s 6s/step - loss: 1.2389 - accuracy: 0.4444 - val_loss: 1.1211 - val_accuracy: 0.5000
# Epoch 10/100
# 1/1 [==============================] - 6s 6s/step - loss: 1.1901 - accuracy: 0.4306 - val_loss: 1.0788 - val_accuracy: 0.5000
# Epoch 11/100
# 1/1 [==============================] - 6s 6s/step - loss: 1.0828 - accuracy: 0.6389 - val_loss: 0.9657 - val_accuracy: 0.5000
# Epoch 12/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.9815 - accuracy: 0.6250 - val_loss: 0.9840 - val_accuracy: 0.5000
# Epoch 13/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.9392 - accuracy: 0.5139 - val_loss: 0.8872 - val_accuracy: 0.5000
# Epoch 14/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.8553 - accuracy: 0.5972 - val_loss: 0.7166 - val_accuracy: 0.6250
# Epoch 15/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.8166 - accuracy: 0.6528 - val_loss: 0.6936 - val_accuracy: 0.6250
# Epoch 16/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.6915 - accuracy: 0.6944 - val_loss: 0.6355 - val_accuracy: 0.6250
# Epoch 17/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.7016 - accuracy: 0.6806 - val_loss: 0.7034 - val_accuracy: 0.6250
# Epoch 18/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.6642 - accuracy: 0.6944 - val_loss: 0.5305 - val_accuracy: 0.7500
# Epoch 19/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.6294 - accuracy: 0.6944 - val_loss: 0.5229 - val_accuracy: 0.7500
# Epoch 20/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.
100
# 1/1 [==============================] - 6s 6s/step - loss: 0.2373 - accuracy: 0.9306 - val_loss: 0.3094 - val_accuracy: 0.8750
# Epoch 52/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.2631 - accuracy: 0.8889 - val_loss: 0.4659 - val_accuracy: 0.7500
# Epoch 53/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.2350 - accuracy: 0.9306 - val_loss: 0.4895 - val_accuracy: 0.7500
# Epoch 54/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.1682 - accuracy: 0.9444 - val_loss: 0.5292 - val_accuracy: 0.7500
# Epoch 55/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.2140 - accuracy: 0.8889 - val_loss: 0.5998 - val_accuracy: 0.6250
# Epoch 56/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.2367 - accuracy: 0.9167 - val_loss: 0.3315 - val_accuracy: 0.8750
# Epoch 57/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.1865 - accuracy: 0.9167 - val_loss: 0.5425 - val_accuracy: 0.7500
# Epoch 58/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.1584 - accuracy: 0.9306 - val_loss: 0.6224 - val_accuracy: 0.7500
# Epoch 59/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.2269 - accuracy: 0.8889 - val_loss: 0.3919 - val_accuracy: 0.7500
# Epoch 60/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.1725 - accuracy: 0.9306 - val_loss: 0.5102 - val_accuracy: 0.6250
# Epoch 61/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.1976 - accuracy: 0.9167 - val_loss: 0.6386 - val_accuracy: 0.7500
# Epoch 62/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.1869 - accuracy: 0.9167 - val_loss: 0.3969 - val_accuracy: 0.7500
# Epoch 63/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.1157 - accuracy: 0.9861 - val_loss: 0.4288 - val_accuracy: 0.8750
# Epoch 64/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.1919 - accuracy: 0.9028 - val_loss: 0.3050 - val_accuracy: 0.8750
# Epoch 65/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.2057 - accuracy: 0.9028 - val_loss: 0.3019 - val_accuracy: 0.8750
# Epoch 66/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.1344 - accuracy: 0.9444 - val_loss: 0.6545 - val_accuracy: 0.7500
# Epoch 67/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.2087 - accuracy: 0.9028 - val_loss: 0.4687 - val_accuracy: 0.8750
# Epoch 68/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.2581 - accuracy: 0.8889 - val_loss: 1.5988 - val_accuracy: 0.6250
# Epoch 69/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.1887 - accuracy: 0.8750 - val_loss: 0.6013 - val_accuracy: 0.8750
# Epoch 70/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.1695 - accuracy: 0.9583 - val_loss: 0.6027 - val_accuracy: 0.7500
# Epoch 71/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.1728 - accuracy: 0.9306 - val_loss: 1.1411 - val_accuracy: 0.6250
# Epoch 72/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.1666 - accuracy: 0.9167 - val_loss: 1.1098 - val_accuracy: 0.6250
# Epoch 73/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.1717 - accuracy: 0.9306 - val_loss: 0.3902 - val_accuracy: 0.7500
# Epoch 74/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.1342 - accuracy: 0.9583 - val_loss: 0.5413 - val_accuracy: 0.7500
# Epoch 75/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.1588 - accuracy: 0.9444 - val_loss: 0.1078 - val_accuracy: 1.0000
# Epoch 76/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.1818 - accuracy: 0.9306 - val_loss: 0.4966 - val_accuracy: 0.7500
# Epoch 77/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0931 - accuracy: 0.9861 - val_loss: 1.0824 - val_accuracy: 0.6250
# Epoch 78/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.2016 - accuracy: 0.9028 - val_loss: 1.1015 - val_accuracy: 0.6250
# Epoch 79/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.2308 - accuracy: 0.9583 - val_loss: 0.4328 - val_accuracy: 0.7500
# Epoch 80/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.1443 - accuracy: 0.9306 - val_loss: 0.6038 - val_accuracy: 0.6250
# Epoch 81/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.4312 - accuracy: 0.8750 - val_loss: 0.8398 - val_accuracy: 0.6250
# Epoch 82/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.1275 - accuracy: 0.9306 - val_loss: 1.0180 - val_accuracy: 0.7500
# Epoch 83/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.1274 - accuracy: 0.9861 - val_loss: 1.3065 - val_accuracy: 0.6250
# Epoch 84/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.1558 - accuracy: 0.9167 - val_loss: 1.5891 - val_accuracy: 0.6250
# Epoch 85/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.1972 - accuracy: 0.9167 - val_loss: 0.3933 - val_accuracy: 0.8750
# Epoch 86/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.1302 - accuracy: 0.9583 - val_loss: 0.4937 - val_accuracy: 0.7500
# Epoch 87/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.2463 - accuracy: 0.9306 - val_loss: 0.3263 - val_accuracy: 0.8750
# Epoch 88/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0635 - accuracy: 0.9861 - val_loss: 0.7264 - val_accuracy: 0.7500
# Epoch 89/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0968 - accuracy: 0.9722 - val_loss: 0.5530 - val_accuracy: 0.7500
# Epoch 90/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.1638 - accuracy: 0.9167 - val_loss: 0.7084 - val_accuracy: 0.7500
# Epoch 91/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.1301 - accuracy: 0.9444 - val_loss: 0.8490 - val_accuracy: 0.7500
# Epoch 92/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.1417 - accuracy: 0.9444 - val_loss: 0.9199 - val_accuracy: 0.6250
# Epoch 93/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0854 - accuracy: 0.9722 - val_loss: 0.5439 - val_accuracy: 0.7500
# Epoch 94/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.1611 - accuracy: 0.9444 - val_loss: 0.5372 - val_accuracy: 0.8750
# Epoch 95/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.1116 - accuracy: 0.9583 - val_loss: 0.5015 - val_accuracy: 0.6250
# Epoch 96/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0800 - accuracy: 0.9722 - val_loss: 0.8421 - val_accuracy: 0.7500
# Epoch 97/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.1279 - accuracy: 0.9444 - val_loss: 0.3416 - val_accuracy: 0.8750
# Epoch 98/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.1080 - accuracy: 0.9583 - val_loss: 0.4915 - val_accuracy: 0.7500
# Epoch 99/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.1234 - accuracy: 0.9444 - val_loss: 0.7718 - val_accuracy: 0.7500
# Epoch 100/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.1005 - accuracy: 0.9583 - val_loss: 1.6027 - val_accuracy: 0.7500

# %%
model.save('phanloaibanh.h5')

# %%
model1=load_model('phanloaibanh.h5')

# %%
import numpy as np
from tensorflow.keras.utils import load_img,img_to_array
img = load_img('banhxeo.jpg', target_size = (100,100))
plt.imshow(img)
img = img_to_array(img)
img = img.reshape(1,100,100,3) 
img = img.astype('float32')
img = img/255
print(label[np.argmax(model.predict(img))])
# Out:
# banhxeo

# %%
import numpy as np
from tensorflow.keras.utils import load_img,img_to_array
img = load_img('dalon.jpg', target_size = (100,100))
plt.imshow(img)
img = img_to_array(img)
img = img.reshape(1,100,100,3) 
img = img.astype('float32')
img = img/255
print(label[np.argmax(model.predict(img))])
# Out:
# banhdalon

# %%
import numpy as np
from tensorflow.keras.utils import load_img,img_to_array
img = load_img('banhhoi.jpg', target_size = (100,100))
plt.imshow(img)
img = img_to_array(img)
img = img.reshape(1,100,100,3) 
img = img.astype('float32')
img = img/255
print(label[np.argmax(model.predict(img))])
# Out:
# banhhoi

# %%
import numpy as np
from tensorflow.keras.utils import load_img,img_to_array
img = load_img('banhuot.jpg', target_size = (100,100))
plt.imshow(img)
img = img_to_array(img)
img = img.reshape(1,100,100,3) 
img = img.astype('float32')
img = img/255
print(label[np.argmax(model.predict(img))])
# Out:
# banhuot
